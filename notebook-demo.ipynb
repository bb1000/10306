# %% [markdown]
# # Notebook demo

# %%
print("Hello")
# Out:
# Hello

# %%
8*7
8*8
# Out:
# 64

# %% [markdown]
# # First level heading
# ## Second level heading
# ### Third level heading

# %% [markdown]
# **bold** *italic*

# %% [markdown]
# Contents of `hello_world.py`:
#
# ```
# print("Hello world!")
# print("Bye")
# ```

# %% [markdown]
# A markdown cheat sheet available [here](https://www.markdownguide.org/cheat-sheet/)

# %% [markdown]
# Mathematics: latex
#
# ~~~
# $$
# f(x) = \int_a^x dt e^t
# $$
# ~~~
#
# generates
#
# $$
# f(x) = \int_a^x dt e^t
# $$

# %% [markdown]
# Images
#
# ![alt text](https://www.markdownguide.org/assets/images/generated/assets/images/book-cover-1080.webp)
#
#
# <img src="https://www.markdownguide.org/assets/images/generated/assets/images/book-cover-1080.webp" alt="alt text" width="50%">
