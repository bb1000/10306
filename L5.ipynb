# %% [markdown]
# # Lecture 5
# ## Working with files
#
# ### The `open` builtin function

# %%
open
# Out:
# <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>

# %%
# open?

# %%
open() # forgetting an argument
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 open() # forgetting an arbument
#
# TypeError: open() missing 1 required positional argument: 'file'

# %%
open('data.txt') # try to open an nonexisting file for reading -> FIleNotFoundError
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 open('data.txt')
#
# File ~/bb1000/.venv/lib/python3.14/site-packages/IPython/core/interactiveshell.py:346, in _modified_open(file, *args, **kwargs)
#     339 if file in {0, 1, 2}:
#     340     raise ValueError(
#     341         f"IPython won't let you open fd={file} by default "
#     342         "as it is likely to crash IPython. If you know what you are doing, "
#     343         "you can use builtins' open."
#     344     )
# --> 346 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.txt'

# %%
# %%file data.txt
# one
# two
# three
# Out:
# Writing data.txt

# %%
f = open('data.txt')

# %%
f
# Out:
# <_io.TextIOWrapper name='data.txt' mode='r' encoding='UTF-8'>

# %% [markdown]
# ### Atttriutes of file object

# %%
dir(f)
# Out:
# ['_CHUNK_SIZE',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %%
f.closed
# Out:
# False

# %%
f.mode
# Out:
# 'r'

# %%
f.name
# Out:
# 'data.txt'

# %% [markdown]
# ### Reading files

# %%
f.read()
# Out:
# 'one\ntwo\nthree\n'

# %%
f.read() # nothing left to read, previous read put f in and end-of-file state'
# Out:
# ''

# %%
open('data.txt').readlines()
# Out:
# ['one\n', 'two\n', 'three\n']

# %%
# with a for loop
for line in open('data.txt'):
    print(line)
# Out:
# one
#
# two
#
# three

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
for line in open('data.txt'):
    print(line.strip())
# Out:
# one
# two
# three

# %%
for line in open('data.txt'):
    print(line, end='')
# Out:
# one
# two
# three

# %%
for line in open('data.txt'):
    print(line.strip(), end='')
# Out:
# onetwothree

# %% [markdown]
# ### Writing

# %%
f = open('bar.txt', 'w')
print('foo', file=f)
print('bar', file=f)
print('baz', file=f)
f.close()

# %% [markdown]
# ### The file pointer

# %%
# file pointer - where are we
f = open('data.txt')

# %%
f.tell()
# Out:
# 0

# %%
f.read()
# Out:
# 'one\ntwo\nthree\n'

# %%
f.tell()
# Out:
# 14

# %%
f.seek(0) # go to beginning
# Out:
# 0

# %%
f.tell()
# Out:
# 0

# %%
f.read(4)
# Out:
# 'one\n'

# %%
f.tell()
# Out:
# 4

# %%
f.closed
# Out:
# False

# %%
f.close()

# %%
f.closed
# Out:
# True

# %%
f.name
# Out:
# 'data.txt'

# %% [markdown]
# ### The context manager: `with`... `as`

# %%
f = open('data.txt')
print(f.read())
f.close()
# Out:
# one
# two
# three

# %%
# a with block - context manager

with open('data.txt') as f:
    print(f.read())
# Out:
# one
# two
# three

# %% [markdown]
# ### Notes for exercises

# %%
# notes for ex 3: list compreshension

#squares = []
#for n in range(10):
#    squares.append(n**2)
#squares
[ n**2 for n in range(10) ]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
